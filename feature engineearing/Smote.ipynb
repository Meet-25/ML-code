# %%
from sklearn.datasets import make_classification
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x,y=make_classification(n_samples=1000,n_redundant=0,n_features=2,n_clusters_per_class=1,
                    weights=[0.95],random_state=1)

# %%
df_x=pd.DataFrame(x,columns=['f1','f2'])
df_y=pd.DataFrame(y,columns=['target'])
df_xy=pd.concat([df_x,df_y],axis=1)

# %%
df_xy['target'].value_counts()
# Out:
# target
# 0    943
# 1     57
# Name: count, dtype: int64

# %%
plt.scatter(df_xy['f1'],df_xy['f2'],c=df_xy['target'])

# %%
from imblearn.over_sampling import SMOTE

oversample=SMOTE()
x,y=oversample.fit_resample(df_xy[['f1','f2']],df_xy['target'])

# %%
y.value_counts()
# Out:
# target
# 1    943
# 0    943
# Name: count, dtype: int64

# %%
y.size
# Out:
# 1886

# %%
df_x=pd.DataFrame(x,columns=['f1','f2'])
df_y=pd.DataFrame(y,columns=['target'])
df_xy_oversample=pd.concat([df_x,df_y],axis=1)

# %%
plt.scatter(df_xy_oversample['f1'],df_xy_oversample['f2'],c=df_xy_oversample['target'])
